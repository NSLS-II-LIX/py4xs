# %%
# %matplotlib notebook

# %%
from exp_setup_Sol import *

# %%
fn = 'data/Sol-s'
buffer_avg = average(get_files_from_fn(fn), detectors, plot_data=True, filter_datasets=False, qmin=0.005, qmax=2.6)
# Out:
# averaging data with Sol-s_000008:
# <img src="data:image/png;base64,..." width="640">

# %%
fn = 'data/Sol-b'
sample_avg = average(get_files_from_fn(fn), detectors, plot_data=True, filter_datasets=False, qmin=0.005, qmax=2.6)
# Out:
# averaging data with Sol-b_000018:
# <img src="data:image/png;base64,..." width="640">

# %%
sample_sub = sample_avg.bkg_cor(buffer_avg, plot_data=True, debug=True, sc_factor=0.995)
# Out:
# background subtraction: Sol-b_0000 - Sol-s_0000
# <img src="data:image/png;base64,..." width="640">
# using scaling factor of 1.006147

# %%
plt.figure()

i0,rg = sample_sub.plot_Guinier(qs=0.016, qe=0.05, fix_qe=True)
plt.xlim((0,0.004))
plt.ylim((5,30))
print("I0=%g, Rg=%.1f" % (i0,rg))
# Out:
# <img src="data:image/png;base64,..." width="640">
# I0=17.1324, Rg=24.3
