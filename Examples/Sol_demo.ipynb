# %%
# %matplotlib notebook

# %%
from exp_setup_Sol import *

# %%
fn = 'data/Sol-s'
buffer_avg = average((get_files_from_fn('data/Sol-s')), detectors, qgrid,
                     plot_data=True, filter_datasets=True, qmin=0.005, qmax=2.6)
# Out:
# Selected Datasets:
# Sol-s_000012
# Sol-s_000011
# Sol-s_000009
# Sol-s_000010
# The following datasets where discarded due to similarity level below the threshold:  0.5
# Sol-s_000008
# averaging data with Sol-s_000012:
# <img src="data:image/png;base64,..." width="640">

# %%
fn = 'data/Sol-b'
sample_avg = average(get_files_from_fn(fn), detectors, qgrid,
                     plot_data=True, filter_datasets=False, qmin=0.005, qmax=2.6)
# Out:
# averaging data with Sol-b_000018:
# <img src="data:image/png;base64,..." width="640">

# %%
sample_sub = sample_avg.bkg_cor(buffer_avg, plot_data=True, debug=True, sc_factor=0.995)
# Out:
# background subtraction: Sol-b_0000 - Sol-s_0000
# <img src="data:image/png;base64,..." width="640">
# using scaling factor of 1.004788

# %%
plt.figure()

i0,rg = sample_sub.plot_Guinier(qs=0.016, qe=0.05, fix_qe=True)
plt.xlim((0,0.004))
plt.ylim((5,30))
print("I0=%g, Rg=%.1f" % (i0,rg))
# Out:
# <img src="data:image/png;base64,..." width="640">
# I0=17.2045, Rg=24.4
# /home/lyang/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib-2.2.2-py3.6-linux-x86_64.egg/matplotlib/axes/_base.py:3449: UserWarning: Attempted to set non-positive ylimits for log-scale axis; invalid limits will be ignored.
#   'Attempted to set non-positive ylimits for log-scale axis; '
