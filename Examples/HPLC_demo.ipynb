# %%
# %matplotlib notebook

# %%
from exp_setup_HPLC import *

# %%
# setting save1d=True will save the data (*.dd) before buffer subtraction (and normalization)
data = get_HPLCdata_from_fns("data/XX", save1d=False)
# Out:
# processing ...
# done. Time elapsed = 160.26 sec

# %%
data1 = get_HPLCdata_from_fns_mp("data/XX", save1d=False)
# Out:
# processing ...
# done. Time elapsed = 51.04 sec

# %%
# setting normalize_int=True makes permanent changes to the data
plot_HPLCdata(data1, 
              uv_file="data/XX_Shimadzu.txt", normalize_int=True,
              buffer_frames=range(29,50),
              calc_Rg=True, thresh=150, qs=0.015, qe=0.05, fix_qe=False,
              #txtfile="t.txt"
             )
# Out:
# <img src="data:image/png;base64,..." width="916">

# %%
batch_subtract_HPLCdata(data1, 25, 50)
# Out:
# averaging data with XX_000026:

# %%
subtract_HPLCdata(data1, 255, 270, 25, 50, sc_factor=0.999, qs=0.01, qe=0.04, fix_qe=True)
# Out:
# averaging data with XX_000256:
# averaging data with XX_000026:
# background subtraction: XX_0002 - XX_0000
# <img src="data:image/png;base64,..." width="640">
# using scaling factor of 0.999000
# <img src="data:image/png;base64,..." width="640">
# I0=11.1875, Rg=45.2
