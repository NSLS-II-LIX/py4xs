# %%
# %matplotlib notebook

# %%
import numpy as np

# %%
from py4xs.hdf import h5sol_HPLC, lsh5
from py4xs import slnxs 
from py4xs.slnxs import trans_mode

# %%
# this is needed to create the processed data 
#     (azimuthal average, merging of data from the 3 detectors)
from exp_setup_09Oct2018 import *
dt = h5sol_HPLC("Lysozyme_5_B.h5", [detectors, qgrid])
dt.process(debug='quiet', N=8, max_c_size=150)
# Out:
# start processing: load_data()
# ['Lysozyme_5_B']
# processing started: sample = Lysozyme_5_B, starting frame = #0
# processing started: sample = Lysozyme_5_B, starting frame = #148
# processing started: sample = Lysozyme_5_B, starting frame = #296
# processing started: sample = Lysozyme_5_B, starting frame = #444
# processing started: sample = Lysozyme_5_B, starting frame = #592
# processing started: sample = Lysozyme_5_B, starting frame = #740
# processing completed:  Lysozyme_5_B 0
# processing started: sample = Lysozyme_5_B, starting frame = #888
# processing completed:  Lysozyme_5_B 148
# processing started: sample = Lysozyme_5_B, starting frame = #1036
# data received: sn=Lysozyme_5_B, fr1=0
# data received: sn=Lysozyme_5_B, fr1=148
# processing started: sample = Lysozyme_5_B, starting frame = #1184
# processing started: sample = Lysozyme_5_B, starting frame = #1332
# processing completed:  Lysozyme_5_B 296
# data received: sn=Lysozyme_5_B, fr1=296
# ...

# %%
# run this when the processed data is already present in the hdf
slnxs.WAXS_THRESH = 10
dt = h5sol_HPLC("Lysozyme_5_B.h5")
dt.load_d1s()

# %%
dt.plot_data(plot_merged=True, clim=[0.9e-2, 1e3])
# Out:
# <img src="data:image/png;base64,..." width="800">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
dt.subtract_buffer(range(1000, 1050), sample_frame_range=range(1165, 1205), normalize_int=True, sc_factor=0.9998)
# Out:
# averaging data with Lysozyme_5_Bmergedf01000:
#  averaging data with Lysozyme_5_Bmergedf01165:
# <img src="data:image/png;base64,..." width="640">

# %%
dt.subtract_buffer(range(1000, 1050), normalize_int=True, sc_factor=0.9998)
# Out:
# averaging data with Lysozyme_5_B_f01000:

# %%
dt.plot_data(plot_merged=False, clim=[0.9e-2, 1e3])
# Out:
# <img src="data:image/png;base64,..." width="800">
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# /home/lyang/pro/pyXS2017/py4xs/hdf.py:788: RuntimeWarning: invalid value encountered in log
#   plt.imshow(np.log(d2), extent=ext, aspect=asp)
